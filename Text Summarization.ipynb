# %% [markdown]
# # Text Summarization

# %% [markdown]
# ### Text summarization Defination
# Text summarization is the process of distilling the most important information from a piece of text while retaining its key meaning and essence. It involves condensing a larger body of text, such as an article, document, or webpage, into a shorter version that captures the main points and essential details.
#
# ### There are generally two main approaches to text summarization:
#
# 1. **Extractive Summarization:** In extractive summarization, key sentences or phrases are selected directly from the original text to form the summary. These selected sentences are typically the ones that contain the most important information or convey the main ideas of the text. Extractive summarization does not generate new sentences but rather reuses existing ones.
#
# 2. **Abstractive Summarization:** Abstractive summarization, on the other hand, involves generating new sentences that convey the main ideas of the text in a concise manner. This approach requires natural language generation techniques to paraphrase and rephrase the original text, often combining information from multiple sentences to create a coherent summary. Abstractive summarization can produce more concise summaries than extractive methods but may introduce some degree of interpretation or paraphrasing.
#
# ### Use Case
# Text summarization is widely used in various applications, including information retrieval, document summarization, news aggregation, and content recommendation systems. It helps users quickly grasp the main points of lengthy texts, saves time, and aids in decision-making and information processing.

# %% [markdown]
# # 5 techniques for text summarization in Python

# %% [markdown]
# ### 1. Gensim
#
# Gensim is a popular Python library primarily used for topic modeling and natural language processing tasks, including text summarization. While Gensim is widely recognized for its topic modeling capabilities, it also offers functionalities for text summarization through algorithms like TextRank and LSA (Latent Semantic Analysis).
#
# Here's how Gensim can be utilized for text summarization:
#
# 1. **TextRank Algorithm**: Gensim provides an implementation of the TextRank algorithm, which is an extractive summarization technique based on the PageRank algorithm used by Google. With Gensim, you can apply TextRank to identify the most important sentences in a document and generate a summary based on their significance.
#
# 2. **LSA (Latent Semantic Analysis)**: LSA is a statistical technique used for dimensionality reduction in natural language processing tasks. Gensim includes functionalities for performing LSA, which can be used for text summarization by extracting the most relevant sentences based on their semantic similarity to the entire document.
#
# 3. **TF-IDF (Term Frequency-Inverse Document Frequency)**: While Gensim is not primarily focused on TF-IDF, it does offer utilities for constructing document-term matrices, which can be useful for implementing TF-IDF-based summarization techniques.
#
#
# Overall, Gensim is a powerful and versatile library for natural language processing tasks, including text summarization, and it offers a range of functionalities to support various summarization techniques.

# %% [markdown]
# ### 2. Sumy
# Sumy is a Python library designed specifically for text summarization. It provides a simple interface for extracting summaries from documents using various algorithms, including some of the techniques mentioned earlier like TextRank and TF-IDF. Sumy aims to make text summarization accessible and easy to implement for Python developers.
#
# Key features of Sumy include:
#
# 1. **Multiple Summarization Algorithms**: Sumy supports several algorithms for text summarization, including TextRank, LSA (Latent Semantic Analysis), LexRank, KL-Sum, and more. This allows users to experiment with different approaches and select the one that best fits their needs.
#
# 2. **Ease of Use**: Sumy offers a straightforward API, making it easy to integrate into Python projects. Users can simply import the library and use its methods to generate summaries from text.
#
# 3. **Customization Options**: While Sumy provides default settings for summarization algorithms, it also allows users to customize parameters such as the number of sentences in the summary or the language of the input text.
#
# 4. **Support for Multiple Languages**: Sumy supports text summarization in various languages, making it suitable for international applications where multilingual support is required.
#
# 5. **Extensibility**: Sumy is designed to be extensible, allowing developers to add custom summarization algorithms or modify existing ones to better suit their specific use cases.
#
# Overall, Sumy is a useful tool for implementing text summarization in Python, particularly for developers who want a quick and easy way to integrate summarization capabilities into their applications without delving into the intricacies of the algorithms themselves.

# %% [markdown]
# ### 3. NLTK
#
# NLTK (Natural Language Toolkit) is a comprehensive Python library for natural language processing (NLP) tasks, including text summarization. While NLTK is more commonly known for its wide range of functionalities for tasks such as tokenization, part-of-speech tagging, and parsing, it also offers tools and resources that can be utilized for text summarization purposes.
#
# Here's how NLTK can be used for text summarization:
#
# 1. **Extractive Summarization using NLTK**:
#    - NLTK provides functionalities for processing text data and computing various metrics that can be used for extractive summarization.
#    - One common approach is to use NLTK for tasks such as sentence tokenization, word tokenization, part-of-speech tagging, and calculating sentence importance scores based on metrics like term frequency, inverse document frequency, and sentence length.
#    - These metrics can then be used to rank sentences and select the most important ones to form the summary.
#
#
# While NLTK provides basic tools for text summarization, more advanced summarization techniques like TextRank or LSA may require additional implementations or integration with other libraries. However, NLTK serves as a valuable resource for building foundational components of text summarization systems in Python.

# %% [markdown]
# ### 4. T5
#
# T5 (Text-To-Text Transfer Transformer) is a state-of-the-art natural language processing (NLP) model developed by Google. It belongs to the Transformer architecture family and is particularly known for its versatility in handling various NLP tasks using a unified "text-to-text" framework. This means that both the inputs and outputs of the model are in the form of text, allowing it to be trained and applied to a wide range of tasks without task-specific modifications.
#
# While T5 was initially introduced for tasks like text generation, translation, and question answering, it can also be adapted for text summarization. The basic idea is to cast the summarization task as a text-to-text transformation problem, where the input text is the document to be summarized, and the output text is the summary itself.
#
# Here's a general outline of how T5 can be used for text summarization:
#
# 1. **Data Preparation**: Prepare a dataset consisting of pairs of documents and corresponding summaries. Each document-summary pair serves as a training example for the model.
#
# 2. **Model Fine-Tuning**: Fine-tune the pre-trained T5 model on the summarization dataset using a sequence-to-sequence learning objective. During fine-tuning, the model learns to generate summaries from input documents.
#
# 3. **Inference**: After fine-tuning, the model can be used to generate summaries for new documents. Given a document as input, the model generates the corresponding summary by decoding the output sequence.
#
# Python libraries such as Hugging Face's `transformers` provide easy-to-use interfaces for working with pre-trained T5 models and fine-tuning them on custom datasets. Here's a simplified example of how you can use `transformers` for text summarization with T5:
#
# T5's strength lies in its ability to handle various NLP tasks using a unified framework, making it a powerful tool for text summarization when fine-tuned on summarization-specific datasets.

# %% [markdown]
# ### 5. GPT-3
#
# GPT-3 (Generative Pre-trained Transformer 3) is a state-of-the-art language model developed by OpenAI. It belongs to the Transformer architecture family, known for its ability to generate human-like text based on a given prompt. While GPT-3 is not specifically designed for text summarization, it can be adapted for this task by framing it as a generative modeling problem.
#
# Here's a high-level overview of how GPT-3 can be used for text summarization:
#
# 1. **Prompting**: Provide GPT-3 with a prompt that includes the input document and a directive to summarize it. The prompt serves as the initial context for GPT-3 to generate the summary.
#
# 2. **Generation**: GPT-3 generates the summary based on the provided prompt. It does so by predicting the most likely continuation of the prompt, which in this case is the summary of the input document.
#
# 3. **Filtering**: Optionally, you can post-process the generated summary to filter out any irrelevant or redundant information and ensure that the output is coherent and concise.
#
#
# While GPT-3 can produce high-quality summaries, it may not always generate concise or coherent summaries, especially for longer documents or when the input prompt is ambiguous. Post-processing and filtering of the generated summary may be necessary to improve its quality.
#
# Overall, GPT-3 offers a powerful and versatile approach to text summarization, leveraging its ability to generate human-like text based on a given prompt.

# %% [markdown]
# ### Installing Necessary Libraries

# %%
! pip install PyPDF2 transformers
! pip install sentencepiece
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\md\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: transformers in c:\users\md\anaconda3\lib\site-packages (4.39.3)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\md\anaconda3\lib\site-packages (from PyPDF2) (4.11.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\md\anaconda3\lib\site-packages (from transformers) (0.4.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\md\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\md\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in c:\users\md\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\md\anaconda3\lib\site-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\md\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\md\anaconda3\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\md\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\md\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: requests in c:\users\md\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\md\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\md\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\md\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp39-cp39-win_amd64.whl (991 kB)
#      -------------------------------------- 991.5/991.5 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0

# %%
pip install --user transformers
# Out:
# Requirement already satisfied: transformers in c:\users\md\anaconda3\lib\site-packages (4.39.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\md\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\md\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\md\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: requests in c:\users\md\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\md\anaconda3\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\md\anaconda3\lib\site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\md\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\md\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: filelock in c:\users\md\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\md\anaconda3\lib\site-packages (from transformers) (1.24.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\md\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\md\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\md\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\md\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (1.26.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\md\anaconda3\lib\site-packages (4.39.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\md\anaconda3\lib\site-packages (from transformers) (0.4.2)
# Requirement already satisfied: filelock in c:\users\md\anaconda3\lib\site-packages (from transformers) (3.6.0)
# Collecting tokenizers<0.19,>=0.14
#   Using cached tokenizers-0.15.2-cp39-none-win_amd64.whl (2.2 MB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\md\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\md\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\md\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: numpy>=1.17 in c:\users\md\anaconda3\lib\site-packages (from transformers) (1.24.4)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\md\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: requests in c:\users\md\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\md\anaconda3\lib\site-packages (from transformers) (21.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\md\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\md\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\md\anaconda3\lib\site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: colorama in c:\users\md\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\md\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Installing collected packages: tokenizers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
# Successfully installed tokenizers-0.15.2

# %% [markdown]
# ## Using T5 for text summarization

# %% [markdown]
# ### Importing necessary libraries

# %%
import PyPDF2
from transformers import T5ForConditionalGeneration, T5Tokenizer

# %% [markdown]
# ### Extracting only text from pdf (graphs/images will not be extracted)

# %%
text = ""
with open(pdf_path, 'rb') as file:
    pdf_reader = PyPDF2.PdfReader(file)
    for page in pdf_reader.pages:
        text += page.extract_text()
print(text)

pdf_path = r"C:\Users\MD\Downloads\“AI OPTIMIZED QUANTUM FOREX BOT TO ENHANCE PHILANTHROPY Evolution and Future Developments”  .pdf"

text = extract_text_from_pdf(pdf_path)
# Out:
# WHITE PAPER
# “AI OPTIMIZED QUANTUM FOREX BOT  TO ENHANCE PHILANTHROPY  Evolution and Future Developments ”
# By Daniel Rosendahl
#
# Introduction
# In the ever -evolving world of finance, currency trading stands as one of its most intricate and dynamic components.
# Traditionally, currency trading —or forex trading (although other trading platforms do exist) —has been the realm of
# institutional investors, financial experts, and a select group of individuals with a deep understanding of global
# economies. Yet,  as with many sectors of the economy, the digital revolution has greatly democratized access, with a
# myriad of platforms now enabling anyone to try their hand at predicting the rise and fall of currency values.
#
# While the barriers to entry have lowered, th e complexities associated with forex trading have concurrently increased.
# Economic events, geopolitical tensions, and a host of other factors can introduce unpredictable volatility. The sheer
# volume of global transactions, occurring 24/7, means that even s easoned traders find it challenging to keep pace with
# the market's movements, let alone consistently make profitable decisions.
#
# This new landscape has necessitated the exploration of advanced technologies to aid in trading decisions. Enter
# Artificial Inte lligence (AI). Over the past decade, AI's role in finance has grown exponentially. From algorithmic stock
# trading to credit risk assessment, AI techniques have proven their value in making sense of vast and complex
# datasets, extracting actionable insights,  and automating decision -making processes.
#
# However, integrating AI into currency trading isn't just about automating trades. It's about leveraging the power of AI
# to make more informed decisions, to understand the intricate web of factors influencing curr ency values, and —
# perhaps most crucially —to minimize the inherent risks of trading. As potential rewards grow, so too do potential
# losses. Thus, the objective isn't merely profitability; it's sustainable and responsible profitability.
#
# This white paper delv es into the creation , development and maturation  of an AI -driven currency trading software bot
# designed not only to navigate the tumultuous seas of forex trading but to do so with a keen eye on risk minimization
# and efficiency . Through a meticulous blend o f advanced algorithmic strategies and prudent financial practices, we
# aim to introduce a tool that transforms how individual and institutional investors approach currency trading.
#
#
# 1. Objectives and Purpose
# The integration of Artificial Intelligence into various sectors has resulted in innovative solutions, showcasing  both
# improved efficiency and precision. In the realm of currency trading, the vastness and dynamism of the forex market
# present atypical  challenges. These challenges underscore the need for creative approaches and tools that can
# navigate this environment adeptly, ensuring not only profitability but also sustainability and resilience against market
# uncertainties.
#
#
# Primary Objectives of this White Paper:
# a. Understanding the Current Landscape: To present a holistic overview of the contemporary forex trading
# environment, emphasizing the complexities and volatilities that traders, both novices and experts, grapple with.
# b. Introducing the AI -Driven Trading Bot: To detail the architecture, mechanis ms, and rationale behind the AI -driven
# software bot designed explicitly for currency trading. This includes insights into data sourcing, algorithmic strategies,
# and real -time decision -making processes.
# c. Emphasizing Risk Minimization: While trading effici ency and profitability are of paramount importance, this paper
# aims to spotlight the equally crucial aspect of risk management. We seek to delineate strategies that the bot employs
# to safeguard investments and ensure long -term, sustainable trading.
#
#
# Purpo se of the AI -Driven Currency Trading Software Bot:
# a. Enhanced Decision -making: To harness the analytical prowess of AI, processing vast amounts of data rapidly to
# make informed trading decisions that may be challenging or time -consuming for human traders.
# b. Automation and Efficiency: To provide traders with a tool that can operate 24/7, monitoring global markets
# continuously, ensuring no opportunity is missed while also executing trades at optimal moments.
# c. Adaptive Learning: Beyond static algorithms, t he bot is designed to learn from the market's patterns and its trading
# outcomes, continuously refining its strategies to improve performance.
#
# Risk Management: In a market notorious for its volatility, the primary purpose of the bot is not just to secure p rofits
# but to do so while actively minimizing potential losses. This involves a combination of AI -driven insights and
# established financial risk management practices.
# a. In essence, the overarching aim of this research and the resulting bot is to offer a s olution that marries the best of
# AI technology with the intricacies of forex trading. It's not about replacing the human trader but augmenting their
# capabilities, providing them with a tool that enhances accuracy, reduces potential pitfalls, and ensures a more
# measured and informed approach to the world of currency trading.
#
#
# 2. Review of Related Literature
# The integration of technology into currency trading has seen multiple evolutionary phases. This literature review
# examines the progression from traditio nal currency trading methods to the introduction of AI techniques, all the while
# highlighting the imperative nature of risk assessment.
# a. Historical Methods of Currency Trading
# Manual Analysis: Traditional forex trading relied heavily on manual analysis. Traders used fundamental methods,
# such as analyzing economic indicators, geopolitical events, and monetary policies. Charts and technical indicators
# were then introduced, which allowed traders to look for patterns and trends in the market.
# Introduction of Electronic Trading: The late 20th century saw the birth of electronic trading platforms. These platforms
# granted traders the ability to make trades in real -time, access international markets, and utilize advanced charting
# tools.
# Algorithmic Trading: With t he surge in computational power, algorithmic trading became popular in the early 2000s.
# This allowed for strategies to be automated, reducing the reaction time to market movements.
#
# b. Existing AI Methods and their Limitations
# Neural Networks: Neural netwo rks, inspired by human brain architecture, were among the first AI techniques applied
# to forex trading. They excelled in recognizing patterns and trends. However, they often required vast amounts of data
# and sometimes overfitted, making them unreliable in changing market conditions.
# Reinforcement Learning: This technique allowed trading bots to learn optimal strategies by interacting with the
# market. While it showed promise in adapting to new information, it was also prone to making erratic decisions if not
# correctly trained.
# Natural Language Processing (NLP): NLP allowed bots to analyze news and derive insights. This added a quasi -
# fundamental analysis aspect to AI trading. The limitation lay in interpreting nuanced language and sentiment
# inaccurately, leadi ng to potential misjudgments.
#
# c. Risk Assessment Techniques
# Value at Risk (VaR): A widely used risk management tool, VaR calculates the maximum potential loss an investment
# portfolio could face for a given confidence interval. However, its limitation is t hat it doesn't predict losses exceeding
# this value.
# Stop-Loss and Take -Profit: These are predetermined price levels at which a position is automatically closed to either
# protect profits or prevent further losses. While effective, they sometimes prematurely  exit positions due to short -term
# market fluctuations.
# Portfolio Diversification: Rooted in the adage "Don't put all your eggs in one basket," diversification involves
# spreading investments across various assets to reduce exposure to any single asset's adv erse movement. The
# limitation here lies in the potential of diluting profits.
#
# In conclusion, while technological advancements, including AI, have considerably reshaped currency trading, they
# come with their unique challenges. A comprehensive understanding  of these historical methods, AI techniques, and
# risk assessment tools is paramount to devising a robust AI -driven currency trading bot.
#
#
#
# 3. Methodology
# The efficacy of an AI -driven currency trading bot hinges on a well -structured methodology. This section delineates our
# approach, encompassing data acquisition, feature engineering, and algorithm selection.
#
# a. Data Acquisition and Preprocessing
# Data Sources
#   i. Historical Data: Acquired extensive datasets from major forex exchange platforms, capturing over a decade of
# minute -by-minute price fluctuations, trade volumes, and other relevant indicators.
#  ii. Real-time Data Streams: Integrated APIs from prominent financial news outlets and forex platforms to fetch real -
# time data and news  updates.
# iii. Sentiment Analysis: Collected data from social media, forums, and financial news sites to gauge market sentiment.
#
# Data Preprocessing
#   i. Cleaning: Removed outliers, addressed missing values using interpolation methods, and standardized dat a formats across different sources.
#   ii. Normalization: Implemented Min -Max scaling to normalize features, ensuring that no particular feature
# disproportionately influences the model.
#  iii. Time -Series Transformation: Segmented data into rolling windows t o facilitate time -series forecasting and
# analysis.
#
# b. Feature Selection and Engineering
# Feature Correlation Analysis: Employed the Pearson correlation coefficient to identify and exclude features with
# multicollinearity, ensuring model interpretability and  robustness.
#    i. Dimensionality Reduction: Utilized Principal Component Analysis (PCA) to reduce the feature set's dimensionality,
# preserving over 95% of the original data variance.
#
# Feature Engineering
#  * Technical Indicators: Introduced features like M oving Averages, Bollinger Bands, and Relative Strength Index to
# help the model recognize common market patterns.
#  * Sentiment Scores: Using NLP techniques, transformed raw sentiment data into quantifiable scores indicating
# positive, neutral, or negative ma rket sentiment.
#
# Algorithm Selection and Rationale
# Preliminary Analysis: Initiated with standard algorithms like Linear Regression and Decision Trees to establish
# baseline performances.
# Deep Learning Approach
#  * Recurrent Neural Networks (RNN): Given their  proficiency with time -series data, RNNs became our primary choice.
# They can recognize patterns over extended time lags, crucial for forex prediction.
#  * Long Short -Term Memory (LSTM): A variant of RNN, LSTM units help in remembering long -term dependencies
# and avoiding the vanishing gradient problem common in traditional RNNs.
#
# Rationale
#  * Given the non -linear and time -dependent nature of forex data, deep learning models like LSTMs offer superior
# predictive capabilities.
#  * Their ability to process vast da tasets aligns with our extensive data acquisition approach.
#  * Previous literature and pilot tests indicated LSTMs' superior performance in forex predictions over other models.
#
# In sum, our methodology amalgamates comprehensive data acquisition with sophis ticated preprocessing, feature
# engineering, and a carefully selected algorithmic approach. The intent is to harness AI's full potential in decoding the
# intricacies of currency trading.
#
#
# 4. AI Model Design
# The backbone of our AI -driven currency trading sof tware bot is its underlying model. This section delves into the
# nuances of the models explored, the finalized architecture, and the training -validation process.
# Exploration of Relevant Models
#
# Neural Networks: These are the foundational layers of interconn ected nodes that process data inputs. While
# traditional feedforward networks were considered, their limitations in handling sequential data made them less ideal
# for our time -series forex data.
#
# Deep Learning:
#   a. Convolutional Neural Networks (CNN): Typically used for image processing, we experimented with CNNs for their
# ability to recognize patterns in localized regions of the data. They exhibited promise in identifying short -term patterns
# but were less adept at longer sequences.
#    b. Recurrent Neur al Networks (RNN): Given their capacity to remember previous inputs in their hidden state, RNNs
# became a primary choice for handling time -series data. However, they come with the challenge of vanishing gradient
# over long sequences.
#    c. Long Short -Term Me mory (LSTM): An advanced variant of RNNs, LSTMs are designed to remember long -term
# dependencies in sequences, addressing the RNN's shortcomings.
# Reinforcement Learning: We explored model -free methods like Q -learning, aiming to have the bot learn optimal
# trading actions through trial and error. While promising, it demanded a significantly longer training time and required a
# careful balance between exploration and exploitation.
#
# Model Architecture
# Model Overview     a. Input Layer: Our model starts with an inp ut layer tailored to accommodate the features derived from our
# preprocessing and feature engineering stages.
#    b. LSTM Layers: Two sequential LSTM layers are used, each comprising 256 units. These layers capture the
# sequential patterns and dependencies in  the forex data.
#    c. Dropout Layer: Introduced to prevent overfitting, a dropout rate of 0.2 ensures that the model remains
# generalizable.
#    d. Dense Layers: Two fully connected dense layers (128 and 64 units, respectively) refine the features extracted  by
# the LSTMs, leading to the final prediction.
#    e. Output Layer: A singular unit outputs the predicted forex value for the next time frame.
#
# Training and Validation
#    a. Training Data Split: 80% of our dataset was utilized for training, ensuring a rich  set of data patterns to teach the
# model.
#    b. Validation Data Split: The remaining 20% was reserved for validation, allowing us to assess the model's
# performance on unseen data.
#    c. Loss Function: Mean Squared Error (MSE) was employed given its sensiti vity to large deviations, making it ideal
# for our goal of precise predictions.
#    d. Optimization Algorithm: Adam optimizer was chosen for its efficiency and adaptability, adjusting learning rates
# on-the-go.
#    e. Early Stopping: To prevent overfitting and  expedite the training process, an early stopping mechanism monitored
# the validation loss, halting training if no improvement was seen over ten consecutive epochs.
#    f. Model Evaluation: Beyond MSE, we employed metrics like Root Mean Squared Error (RMSE) and Mean Absolute
# Percentage Error (MAPE) to understand the model's accuracy and deviation from actual values.
#
# In essence, our Enhanced AI model design is a product of rigorous planning, review, testing, experimentation,
# iterative refinement, and validati on, all aimed at achieving unparalleled accuracy in currency trading predictions.
#
#
# 5. Risk Minimization Strategies
# While our AI -driven currency trading software bot is designed for optimal decision -making, the inherently volatile
# nature of forex markets n ecessitates a robust framework of risk minimization. This section outlines the strategies
# implemented to safeguard investments and mitigate potential losses.
#
# Portfolio Diversification
#    a. Rationale: No currency pair or trading strategy is immune to adve rse movements. Diversifying investments
# across multiple currency pairs can buffer against localized economic shocks or geopolitical events affecting a
# particular currency.
#    b. AI-Driven Diversification: Our bot is programmed to analyze correlations betwe en different currency pairs,
# ensuring investments are spread across low -correlated pairs. This dynamic adjustment aims to reduce risk while
# capitalizing on potential opportunities in various markets.
#    c. Currency Pair Groups: The bot classifies currency pairs into major, minor, and exotic pairs. A balance between
# these groups ensures a blend of stable trades (from major pairs) and high -reward potential trades (from exotic pairs).
#
# Stop-Loss and Take -Profit Mechanisms
# Proactive Management: Our bot does not  rely solely on predictive analytics. It sets predetermined stop -loss and take -
# profit points for each trade, ensuring automatic exit during rapid unfavorable movements or when desired profits are
# attained.
#    a. Dynamic Adjustment: These thresholds aren't static. The bot analyzes market volatility, news sentiment, and
# technical indicators, adjusting the stop -loss and take -profit points to align with the current market landscape.
#    b. Protection against Flash Crashes: Such mechanisms are crucial in forex ma rkets known for sudden "flash
# crashes." They ensure that even during unforeseen market disruptions, losses are curtailed.
#
# Money Management Rules
#    a. Fixed Fractional Position Sizing: The bot is designed to invest only a fixed percentage of the portfolio  on a single
# trade. This ensures that even in a series of losing trades, a significant portion of the portfolio remains preserved. Loss
# Limiting: To prevent extended drawdown periods, the bot incorporates a daily and monthly loss limit. If losses reach a
# predetermined percentage of the portfolio, trading is halted, allowing for re -evaluation and preventing emotion -driven
# trading decisions .
#    b. Conservative Leverage: While leverage can amplify profits, it equally magnifies potential losses. Our bot employs
# conservative leverage, ensuring that trades don't expose the portfolio to undue risk.
#    c. Continuous Monitoring: Money management is n't a set -and-forget strategy. The bot continuously monitors
# portfolio health, adjusting trading behavior based on past performance and future risk assessments.
# In conclusion, the integration of these risk minimization strategies ensures that our AI -drive n currency trading
# software bot operates within a framework of prudence and caution. While the forex market's allure often lies in its
# high-reward potential, our primary objective remains the preservation of capital and long -term sustainable growth.
#
#
# 6. Testing and Validation
# Ensuring the performance, reliability, and safety of our AI -driven currency trading software bot necessitates a rigorous
# testing and validation process. This section breaks down the methodologies employed,  and metrics utilized to aff irm
# the bot's efficacy.
#    a. Back -testing Methodology
#    b. Scope of Data: Utilized over a decade of historical forex data, ensuring our bot's strategies were tested against a
# plethora of market conditions, ranging from bull markets, bear markets, to peri ods of high volatility.
#    c. Slippage and Commission: Realistic trading costs were incorporated, accounting for potential slippage during
# trade execution and standard brokerage commissions.
#    d. Strategy Evaluation: The bot's trading decisions were evalu ated against the historical data, visualizing how the
# strategy would have performed historically.
#    e. Limitations Acknowledged: While back -testing provides valuable insights, it operates on the premise of hindsight.
# We're aware that past performance does n't guarantee future results, but the process provides a foundational
# confidence in the bot's decision -making.
#
#
# 7. Forward -testing or Paper Trading  and Evaluation Metrics
#    a. Real-time, Risk -free Environment: The bot was set to run in a simulated tradin g environment using real -time
# market data, allowing us to observe its decision -making and performance without actual financial risk.
#    b. Duration: Forward -testing spanned a period of six months, ensuring exposure to a varied set of market
# conditions.
#    c. Comparison to Back -testing: Results were juxtaposed with back -testing outcomes to discern any discrepancies
# and ensure that the bot's performance wasn't merely an artifact of historical data overfitting.
#    d. Sharpe Ratio: This metric evaluates the return of an investment compared to its risk. Our bot consistently
# demonstrated a Sharpe Ratio above 2.5 during testing, indicating a favorable risk -adjusted return.
#    e. Drawdown: Monitoring the largest drop from a peak in the portfolio val ue, our bot's maximum drawdown during
# testing was limited to 12%. This is well within our risk tolerance, affirming the bot's resilience during unfavorable
# market conditions.
#    f. Return on Investment (ROI): Over the combined back -testing and forward -testing periods, the bot showcased an
# ROI of 18%. This is competitive when juxtaposed against traditional forex trading benchmarks.
#
# In essence, through meticulous back -testing, real -time forward testing, and rigorous evaluation metrics, we've
# endeavored to en sure our AI -driven currency trading software bot is not just theoretically robust but also
# pragmatically effective. While every trading strategy carries inherent risks, our exhaustive testing and validation
# processes aim to imbue confidence in the bot's ca pabilities and potential for consistent returns.
#
#
#
#
# 8. Results
# The bedrock of any technological or financial innovation lies in tangible results. In this section, we dissect the
# performance of our AI -driven currency trading software bot, juxtaposing it ag ainst industry benchmarks and
# highlighting its risk management efficacy.
# Performance of the Bot compared to benchmarks
#     a. Bot's Annual Return: Over the span of one year, our bot achieved an impressive quantized annual return of 24%
# average with a best case average range of 76%+ , surpassing the average return of forex traders and other AI -driven
# solutions in the market.
# Comparison with Industry Benchmarks
#    b. Average Forex Trader: According to recent data, the average individual forex trader achieves a n annual return of
# around 10%. Our bot's performance more than doubles this metric.
#    c.  AI-Driven Competitors: Recent surveys suggest that leading AI -driven trading software average an annual return
# of 18%. Once again, our solution stands out with a not able margin of outperformance.
#    d. Trade Success Rate: Our bot registered a trade success rate of 78%, indicating that more than three out of four
# trades ended profitably. This is significantly above the industry average of 60% for individual traders.
#
#  9. Analysis and Dissection of Risk Management Efficacy
#    a. Drawdown Analysis:
#  - Maximum Drawdown: While the forex market witnessed some tumultuous phases, the bot's maximum drawdown
# remained limited to 12%, which is lower than the industry average of 20%. This reaffirms the bot's robust risk
# management strategies.
#  - Frequency of Drawdowns: Over the year, the bot experienced a total of six notable drawdown periods, swiftly
# recovering from five within a week. This rapid recovery underscores t he bot's adaptability and resilience.
#    b. Portfolio Diversification Impact:
#  - By investing in a balanced mix of major, minor, and exotic currency pairs, the bot's portfolio showcased less
# volatility when compared to portfolios focused on single currency  pairs or categories.
#    c. Effectiveness of Stop -Loss and Take -Profit:
#  - These mechanisms were triggered in 30% of the trades. Out of these, 65% were stop -loss activations during rapid
# market downturns, thereby curtailing losses. The remaining 35% were t ake-profit activations, ensuring that the bot
# captured profits at desired thresholds.
#  - Money Management Review: The bot's fixed fractional position sizing strategy ensured that even during a series of
# unfavorable trades, 80% of the portfolio remained unt ouched and preserved. This proactive money management
# played a pivotal role in the bot's impressive annual return.
#
# In summary, the results underscore not just the bot's capability to generate substantial returns, but also its diligence
# in risk management,  ensuring that profits don't come at the expense of unwarranted risks. Our solution, when
# measured against industry standards and benchmarks, showcases a promising blend of performance and safety.
#
#
# 10. Discussion
# In the realm of AI -driven solutions, resul ts not only speak to the immediate efficacy of the system but also to the
# broader implications of its design, strategy, and adaptability. Herein, we dissect our findings, potential enhancements,
# and the roadblocks encountered during the development of our currency trading software bot.
#
#    a. Insights drawn from the Results
#  -Outperforming the Status Quo: The bot's superior performance, both in terms of ROI and trade success rate,
# suggests that AI -driven strategies can considerably enhance trading outcomes compared to traditional methods and
# existing AI solutions.
#  -Risk-Adjusted Returns: The bot's high Sharpe Ratio and limited drawdowns emphasize that its returns are  not
# merely a product of high risk , but rather strategic trades and robust risk management.
#  -Adaptability and Resilience: The bot's rapid recovery from drawdowns highlights its ability to adjust to changing
# market dynamics, an essential trait in the tumultuous world of forex trading.
#
#    b. Potential Improvements and Innovations
#  -Real-time New s Integration: While the bot currently factors in historical news sentiment, integrating real -time news
# analytics could further refine its trading decisions, especially during major geopolitical events.
#  -Alternative Machine Learning Models: Exploring mode ls beyond neural networks, such as ensemble methods or
# hybrid systems, might lead to more diverse trading strategies and potentially higher returns.
# * Customizable Risk Appetite: Future iterations could allow users to set their risk appetite, allowing the bot to adjust
# its strategies accordingly, catering to both conservative and aggressive traders.
#
#    c. Challenges Faced and Solutions Proposed
#  -Overfitting Concerns: One of the initial challenges was the bot's propensity to overfit on historical data. Thi s was
# addressed by introducing regularization techniques and ensuring comprehensive forward -testing.
#  -Handling Market Anomalies: Black swan events posed unpredictable challenges. Incorporating stop -loss
# mechanisms and diversification strategies helped mit igate potential losses during such anomalies.
#  -Latency Issues: In the early stages, there were latency issues in executing trades, leading to slippage. This was
# rectified by optimizing the bot's codebase and partnering with faster data feeds.
#
# In conclusi on, while our AI -driven currency trading software bot showcases promising results and innovations, we
# acknowledge the continuous evolution of financial markets and technology. We remain committed to iterating,
# improving, and ensuring that our solutions rem ain at the forefront of trading excellence.
#
#
#
# 11. Ethical Considerations
# As we propel forward into the era of AI -driven financial solutions, ethical considerations emerge as paramount.
# Beyond mere profitability, it's imperative that our currency trading s oftware bot operates within an ethical framework, ensuring fairness, transparency, and accountability.
#
#    a. Ensuring Fairness and Avoiding Biases
#  -Data Integrity and Diversity: We've curated our training data from diverse and globally representative sources. This
# ensures our bot doesn't inadvertently favor specific currency pairs or regions and remains impartial in its decision -
# making.
#  -Bias Detection Algorithms: To fortify our stance on fairness, we've incorporated bias detection algo rithms. These
# constantly screen for potential trading biases, enabling real -time adjustments to the bot's strategies if discrepancies
# are detected.
#  -Transparent Algorithms: While our models employ complex neural networks, we strive for transparency by pro viding
# detailed explanations of our bot's decisions upon request. This demystifies its operations and reassures users of its
# impartiality.
#
#    b. Avoiding Market Manipulations
#  -Volume Restrictions: Our bot is coded to refrain from placing trades that coul d significantly alter the market volume,
# ensuring it doesn't inadvertently manipulate currency prices.
#  -Ethical Trading Guidelines: Our software adheres to a strict set of ethical guidelines that prohibit any form of market
# cornering, pump -and-dump strate gies, or other manipulative tactics.
# - Regular Audits: To uphold our commitment to ethical trading, our bot undergoes periodic third -party audits. This
# ensures its trading patterns remain compliant with international trading regulations and standards.
#
#    c. Responsibility in Financial Decision -making
#  -Educational Emphasis: While our bot facilitates automated trading, we actively promote user education. We provide
# comprehensive resources, ensuring users understand the intricacies of forex trading and the u nderlying strategies
# employed by our bot.
# - Disclaimers and Risk Warnings: Users are consistently reminded that all trading involves risks. Prior to using the
# bot, they're required to acknowledge comprehensive disclaimers detailing potential financial risk s.
#  -Human Oversight: While the bot operates autonomously, our team of financial experts continually monitors its
# activities. This ensures that if market conditions become extremely volatile or unpredictable, human intervention can
# guide the bot's strategi es, safeguarding user interests.
#
# In charting the path for AI in finance, it  is our conviction that ethical considerations should be at the core of innovation.
# We endeavor to meld technological prowess with ethical responsibility, ensuring our currency tra ding software bot
# stands as a paragon of both profitability and integrity.
# * Appendices L: Ethics Reference
#
#
#
# 12. Future Work and Enhancements
#
# Future Work and Enhancements
#
# As the landscape of AI and financial technology is ever -evolving, our commitment to progress remains undeterred.
# The current success of our AI -driven currency trading software bot is just the starting point. Here, we discuss
# potential avenues for future work and improvements.
#
#    a. Scalability Concerns
#  -Enhanced Infrastructure: To ca ter to a growing user base and manage increasing trade volumes, we're investing in
# expanding our computational and data infrastructure. This ensures smooth bot performance irrespective of scale.
#  -Distributed Systems: To ensure global reach and fault toler ance, we're exploring the implementation of distributed
# systems, enabling seamless trading activities across multiple geographical locations.
#
#    b. Employing Emerging AI Techniques
#  -Evolving Learning Models: With rapid advancements in AI, newer learning models emerge frequently. Our R&D
# team is actively researching the feasibility and integration of such models to further refine trading strategies.
#  -Adaptive Learning: Rather than relying solely on periodic model updates, we're aiming to incorporate adapt ive
# learning techniques, allowing the bot to evolve its strategies in real -time based on new data.
#
#    c. Forecasting and Incorporating Quantum Computing Technology
#  -Research Collaboration: We're in preliminary talks with quantum computing firms to explor e potential collaborations.
# Quantum computers, with their promise of unparalleled computational speed, could revolutionize real -time data
# analysis for trading.   -Quantum -Ready Algorithms: To prepare for this future, our team is working on quantum -ready alg orithms. These
# are designed to seamlessly transition into quantum computing environments once they become commercially viable
# for trading.
#
#    d. Expanding to Other Financial Instruments
#  -Equity Markets: Given the success in forex trading, we're researching the adaptation of our bot for stock market
# trading, capitalizing on the vast opportunities in equity markets worldwide.
#  -Cryptocurrencies: With digital currencies becoming a mainstay in global finance, we're in the early stages of testing
# our bot's strategies in cryptocurrency markets.
#  -Commodities and Indices: Expanding our horizons, future versions of our bot may cater to trading in commodities
# like gold, oil, and global indices, providing users with a diversified trading portfolio.
#
# In wrap ping up, our journey in refining and enhancing our currency trading software bot is continuous. With a keen
# eye on the future, we remain poised to embrace new technologies, tackle challenges, and expand our offerings,
# ensuring our users always have the cut ting-edge advantage in the dynamic world of finance.
#
#
#
# 13. Conclusion
# The labyrinthine world of currency trading, with its volatile twists and turns, has long sought solace in technology.
# Through our meticulous research and innovation, our aim is to be at  the forefront of  a new era with our AI -driven
# currency trading software bot, poised to revolutionize trading paradigms.
#
#    a. Summarizing the Significance of the AI -driven currency trading bot
# The significant strides we've made go beyond mere profitabili ty. The bot's blend of advanced AI techniques, refined
# data analytics, and strategic foresight have positioned it as a vanguard in forex trading. Its adaptive learning
# capabilities, ethical trading practices, and robust risk management systems attest to th e harmony of cutting -edge
# technology and financial acumen.
#
#    b. Reiterating the importance of minimizing risk
# While the allure of high returns in forex trading is undeniable, the shadows of risk loom large. Our endeavors have
# consistently prioritized ris k minimization. From diversified portfolios to intelligent stop -loss mechanisms, every facet of
# our bot is designed with the user's financial safety at its core. It's not just about winning the race; it's about ensuring
# the journey is as smooth and secure as possible.
#
# In culmination, our AI -driven currency trading software bot stands as a beacon, illuminating the path for traders
# worldwide. In marrying technology and ethical responsibility, we offer not just a tool, but a trusted ally in the complex
# dance of global finance. As we look to the future, our commitment remains unwavering: to deliver excellence,
# innovation, and safety to every user.
#
# 14. Acknowledgments
# Embarking on the journey to develop and research our AI -driven currency trading software bot w as no solitary
# endeavor. We deeply appreciate the amalgamated wisdom of countless researchers, contributors, and visionaries.
# Their works served as foundational pillars and guiding lights for our own exploration.
#    a. Recognition of Previous Research and Web References
# Our first debt of gratitude is to the academic researchers whose invaluable contributions made the complexities of AI
# and forex trading more accessible. A particular nod to Dr. Julia Fernandes' seminal paper on "AI Trends in Currency
# Markets ," accessed via the Forex Analytics  online portal, which provided both inspiration and substantive technical
# direction.
#    b. Contributors Resourced on the Web
# The digital age blessed us with online platforms bursting with collective insights. We wish to e xpress our heartfelt
# gratitude to contributors on the ForexTechTalk forum and the AIinTrade subreddit. Special mention to user
# 'ForexGuru2022' for their in -depth thread on neural network optimizations and 'AI_Trader_Expert' for the enlightening
# discussions  on reinforcement learning in trading.
#    c. Other Technical Papers on Bot Software
# Technical white papers were instrumental in shaping our perspectives and methodologies. We extend our
# appreciation to authors like Dr. Alexei Morozov for his paper "Reinven ting Bots: The Next Gen of Trading Softwares"
# and Dr. Lina Patel's "Quantitative Techniques in AI -Driven Forex Bots" – both of which critically influenced our
# software's design and logic.
#    d. Other Preeminent Builders of Currency Software Bots
# Last but n ot least, the world of currency software bots boasts some true pioneers whose work laid the groundwork for
# innovation. We are indebted to the visionary work of firms like ForexTech Innovators Inc. and individuals like Mr. Rajan Khanna, the mind behind the famed 'KhannaFX' trading bot.
#
# In summation, while our software stands as a testament to our team's dedication and innovation, it is, in essence, a
# mosaic – pieced together from the vast knowledge and experiences of many. To all those unnamed but influenti al
# sources, workshops attended, and late -night webinars, thank you.
#
# 15. References
# a. Aghion, P., & Howitt, P. (1998). *Capital Accumulation and Innovation as Complementary Factors in Long -Run
# Growth*. Journal of Economic Growth, 3(2), 111 -130.
# b. Brown, M., & Goetzmann, W. (2001). *Hedge Funds With Style*. The Journal of Portfolio Management, 29(2), 101 -
# 112.
# c. Chen, L., & Zhao, H. (2009). *Portfolio Choices with Orthogonal Neural Network Factors*. Oxford Bulletin of
# Economics and Statistics, 71(3) , 379 -405.
# d. ForexTradeBotTech. (2019). *An Overview of Current AI Models in Forex Trading*. [Online].
# Available:  www.forextradebottech.com/models -overview
# e. Granger, C. W. (1969). *Investigating Causal Relations by Econometric Models and Cross -spectral Methods*.
# Econometrica: Journal of the Econometric Society, 424 -438.
# f. Heaton, J., Polson, N., & Witte, J. H. (2017). *Deep Learning in Finance*. arXiv prep rint arXiv:1602.06561.
# g. LeCun, Y., Bengio, Y., & Hinton, G. (2015). *Deep Learning*. Nature, 521(7553), 436 -444.
# h. Minsky, H. P. (1986). *Stabilizing an Unstable Economy*. Yale University Press.
# i. RMTechForum. (2020). *Discussion: Limitations of Curren t Bot Strategies in Forex*. [Online Forum].
# Available:  www.rmtechforum.com/forex -bot-limitations
# j. Sutton, R. S., & Barto, A. G. (2018). *Reinforcement Lear ning: An Introduction*. MIT press.
# k. Thompson, J., & ForexSoftInnovations. (2018). *Harnessing Quantum Computing in Currency Trading*. White
# Paper. ForexSoftInnovations Publications.
# l. Williams, R. (2012). *Trading on Multiple Frequencies: A Comprehensiv e Analysis*. Financial Analysts Journal,
# 68(3), 42 -54.
# m. Zhang, L., & Tan, K. (2018). *A Review of Techniques for Risk Management in Trading Systems*. Journal of
# Financial Markets, 40, 1 -15.
# n. Almgren, R., & Chriss, N. (2000). Optimal execution of portfo lio transactions. *Journal of Risk*, 3, 5 -40.
# o. Bertsimas, D., & Lo, A. W. (1998). Optimal control of execution costs. *Journal of Financial Markets*, 1(1), 1 -50.
# p. Chan, L. K., & Lakonishok, J. (1995). The behavior of stock prices around institutional t rades. *Journal of Finance*,
# 50(4), 1147 -1174.
# q. Goodfellow, I., Bengio, Y., & Courville, A. (2016). *Deep Learning*. MIT Press.
# r. Huang, W., Zheng, H., & Chia, J. Y. (2015). Neural network -based mean -variance -skewness model for portfolio
# optimization. * Computers & Operations Research*, 61, 124 -137.
# s. Kearns, M., & Nevmyvaka, Y. (2013). *Machine Learning for Market Microstructure and High -Frequency Trading*.
# In Handbook of Financial Markets.
# t. Kissell, R. (2013). *The science of algorithmic trading and portfolio management*. Academic Press.
# u. Mitchell, T. (1997). *Machine Learning*. McGraw Hill.
# v. Moody, J., & Saffell, M. (2001). Learning to trade via direct reinforcement. *IEEE Transactions on Neural
# Networks*, 12(4), 875 -889.
# w. Murphy, K. P. (2012).  *Machine learning: a probabilistic perspective*. MIT Press.
# x. Prado, M. L. D. (2018). *Advances in financial machine learning*. Wiley.
# y. Ritter, G. (2017). Machine learning for trading. In *Handbook of computational finance*. Springer.
# z. Silver, D., Huang, A., Maddison, C. J., Guez, A., Sifre, L., Driessche, G. V., ... & Hassabis, D. (2016). Mastering the
# game of Go with deep neural networks and tree search. *Nature*, 529(7587), 484 -489.
# aa. Sutton, R. S., & Barto, A. G. (2018). *Reinforcement learnin g: An introduction*. MIT Press.
# bb. Vaswani, A., Shazeer, N., Parmar, N., Uszkoreit, J., Jones, L., Gomez, A. N., ... & Polosukhin, I. (2017). Attention
# is all you need. *Advances in neural information processing systems*, 30.
# *APA, MLA, or Chicago for sou rces. connect  via public databases, online access, or libraries
#
#
#
#
# 16. Appendices  A: Provides detailed pseudocode for the main trading algorithm.
# ```pseudo
# BEGIN
#    Load historical price and volume data
#    Preprocess data: normalize and remove outliers
#    Split data: 80% training, 20% testing
#    Initialize model parameters     FOR each epoch DO
#        Predict market movement using current model
#        Calculate loss with respect to real market movement
#        Backpropagate the error to update model paramete rs
#    END FOR
#    IF prediction is bullish THEN
#        Execute buy order
#    ELSE
#        Execute sell order
#    END IF
# END
# ```
#
#
# Appendices B: Deep Learning Model Architecture
# *Visual diagrams illustrating the neural network structure, layer details, and neuron interconnections. Descriptive
# annotations for each layer, e.g., convolutional layers, LSTM cells, or dense layers.
#
#
# Appendices C: Sample Code Snippets
# *Python -based code snippets showcasing key aspects of the model:
# ```python
# # Load data using pand as
# import pandas as pd
# data = pd.read_csv('historical_data.csv')
#
# # Initializing a simple LSTM model using TensorFlow
# import tensorflow as tf
# model = tf.keras.Sequential([
#    tf.keras.layers.LSTM(50, return_sequences=True, input_shape=(data.shape[1], 1)),
#    tf.keras.layers.Dropout(0.2),
#    tf.keras.layers.LSTM(50),
#    tf.keras.layers.Dense(1)
# ])
# model.compile(optimizer='adam', loss='mean_squared_error')
# ```
#
#
# Appendices D: Data Analysis and Preprocessing
# Appendix: Data Analysis and Preprocessing for AI Currency Trading Bot
#
# 1. Data Collection
#
#    a. Definition: The gathering of relevant data from various sources.
#    b. Importance: Raw data forms the foundation for any AI analysis.
#    c. Sources: Economic databases, social media APIs,  influencer channels, political disclosures, and tech platforms.
#    d. Discussion: Collection methods, such as web scraping, direct APIs, and third -party aggregators, should be
# employed. The process should prioritize accuracy, timeliness, and relevance. Re dundancies and overlaps should be
# addressed to avoid data duplication.
#
# 2. Data Cleaning
#
#    a. Definition: Removing or correcting data inaccuracies or inconsistencies.
#    b. Importance: Erroneous data can mislead AI models, leading to inaccurate predictio ns.
#    c. Methods: Outlier detection, null value handling, and error correction.
#    d. Discussion: Depending on the data source, various cleaning techniques should be applied. For instance, social
# media data may require removal of bots or spam, while econo mic data may need corrections for revised historical
# figures.
#
#
# 3. Data Integration
#     a. Definition: Combining data from multiple sources to provide a unified view.
#    b. Importance: Allows the AI model to draw insights from various data points.
#    c. Methods: Data warehousing, database merging, and alignment of different data formats.
#    d. Discussion: Care must be taken to ensure that data from various sources is compatible. Timestamps, for
# instance, need to be aligned to ensure events from different so urces correspond correctly.
#
#
# 4. Data Transformation
#
#    a. Definition: Converting data into a suitable format or structure for analysis.
#    b. Importance: Ensures data is in a consistent form for modeling.
#    c. Methods: Normalization (scaling all numeric al variables to a standard range), encoding categorical variables, and
# feature engineering.
#    d. Discussion: For example, sentiments from social media might be encoded into positive, neutral, or negative
# categories, or influencers' opinions could be trans formed into a numerical trustworthiness score.
#
#
#
# 5. Data Reduction
#
#    a. Definition: Simplifying the data structure, making it more manageable and efficient for analysis.
#    b. Importance: Speeds up the modeling process without losing crucial information .
#    c. Methods: Principal component analysis (PCA), feature selection, and binning.
#    d. Discussion: Reducing dimensionality can help in focusing on the most impactful data points. For instance, not all
# tweets might be relevant for forex trading; hence, a feature selection method might prioritize those from financial
# analysts or news outlets.
#
#
# 6. Data Discretization
#
#    a. Definition: Transforming continuous data into discrete forms.
#    b. Importance: Helps in handling continuous data more effectively in certain modeling scenarios.
#    c. Methods: Binning, histogram analysis, and clustering.
#    d. Discussion: Exchange rates, which are continuous, might be discretized into categories like 'rising', 'stable', and
# 'falling' to predict broad mark et trends instead of specific values.
#
# 7. Data Exploration
#
#    a. Definition: Detailed analysis of the data to identify patterns, anomalies, or relationships.
#    b. Importance: Offers insights that guide the modeling process.
#    c. Methods: Statistical ana lysis, visualizations, and correlation matrices.
#    d. Discussion: For example, visualizing sentiment analysis results against currency value changes might reveal
# correlations between public sentiment and market movement.
#
# Conclusion
# A rigorous approach to  data analysis and preprocessing is paramount for the success of an AI currency trading bot.
# Each step, from collection to exploration, ensures that the AI model receives high -quality, relevant, and structured
# data. Given the volatility and complexity of f orex markets, taking meticulous care in preparing data is a crucial step
# towards achieving accurate and actionable insights.
#
#
#
# Appendices E: Data Before and After Preprocessing
# Before Preprocessing:
#     a. Raw data often contains noise, inconsistencies, a nd may lack structure.
#     b. Example: Tweets may contain emojis, URLs, or non -textual elements; economic data might come with
# annotations or footnotes; influencer opinions might be in free -form text.
#
# After Preprocessing:
#      a. Data is structured, cle aned, and formatted for AI analysis.
#      b. Example: Tweets are reduced to sentiment scores or categorical values (positive, negative, neutral); economic
# data is parsed into structured tables; influencer opinions are encoded as trust scores.
#
# Descriptive  Statistics Tables
# A descriptive statistics table provides an overview of the central tendencies, spread, and shape of data distribution.
# Here's a generic structure:
#
# | Feature | Count | Mean | Median | Mode | Std. Deviation | Min | Max |
#
# Discussion: This  table offers an initial understanding of data, its variability, and potential outliers. For instance, a high
# standard deviation in sentiment scores might indicate volatile public opinion.
#
# Handling Missing Data  - Missing or omitted data can skew results a nd reduce the statistical power of the model.
#  Methods:
#      a. Deletion: Removing any row with missing data. Effective for random, infrequent missing data.
#      b. Mean/Median Imputation: Filling missing values with the mean or median of the data column.
#      c. Mode Imputation: For categorical data, replacing missing data with the mode.
#      d. Prediction Models: Using models like linear regression or k -NN to predict and impute missing values.
#      e. Forward/Backward Fill: In time -series data, using previous or next data points to fill gaps.
#  Discussion:
# ...
# most up -to-date information. This is particularly vital for forex trading, where markets can move rapidly based o n fresh
# data.
#
# b. Indicator Weighting
#  - Definition: The process of determining the significance of each economic indicator in relation to the AI's trading
# decisions.
#  - Importance: Not all indicators influence the forex market equally. Weighting ensures t he most relevant indicators
# have the appropriate influence on trading strategies.
#  - Sources: Historical forex market data, academic research on economic indicators' impact.
#  - Discussion: An AI bot might, for example, give higher weighting to interest rat e decisions compared to retail sales
# data based on historical market reactions. This weighting can be dynamic, adjusting based on current market
# conditions.
#
# c. Predictive Analysis
#  - Definition: The use of statistical algorithms and machine learning techn iques to identify the likelihood of future
# outcomes based on historical data.
#  - Importance: Allows the bot to forecast market movements and make informed trading decisions ahead of the curve.
#  - Sources: Historical forex market data, past economic indicat ors, machine learning models.
#  - Discussion: AI bots analyze patterns from past data to anticipate how the market will react to certain economic
# indicators. This involves training machine learning models on vast datasets to refine predictions continually.
#
# d. Risk Management
#  - Definition: Strategies employed by AI bots to minimize potential losses in forex trading.
#  - Importance: Forex markets can be volatile. Effective risk management ensures profitability even when some trades
# don't go as predicted.
#  - Sources: Built -in algorithms within the bot, user -defined risk parameters, and real -time market data.
#  - Discussion: This might include setting stop -loss orders, diversifying trading strategies, or adjusting trading volume
# based on market volatility. AI bot s can also assess economic data to determine overall market risk, scaling back
# trades in uncertain times.
#  5. Limitations
#
# a. Data Accuracy
#   - Definition: The extent to which the collected economic data represents the true state of an economy.
#   - Importa nce: Erroneous data can lead to misinformed trading decisions.
#   - Sources: Discrepancies in reporting from different agencies, methodological changes in data collection.
#   - Discussion: Even official sources can revise their economic data retrospectively,  which can create challenges for
# AI bots relying on real -time information.
#
# b. Lagging Indicators
#   - Definition: Indicators that offer insights into past economic performance rather than current or future states.
#   - Importance: Relying heavily on lagging  indicators can make an AI bot reactive rather than proactive.
#   - Sources: GDP and unemployment rates are common lagging indicators.
#   - Discussion: While these indicators provide valuable insights, they might not always be the best predictors of future
# market movements, especially in rapidly changing economic landscapes.
#
# c. Overfitting
#   - Definition: A modeling error in which an AI algorithm captures noise rather than the underlying data pattern.
#   - Importance: Can lead the AI bot to make predictions b ased on irrelevant or random patterns.
#   - Sources: The complexity of AI models, especially when trained on limited datasets.
#   - Discussion: It's crucial to regularly validate and test AI models against new data to ensure they generalize well and
# aren't o verfitting.
#
# d. Market Sentiment
#   - Definition: The collective attitude of traders towards the forex market or a particular currency pair.
#   - Importance: Economic indicators alone don't capture the full picture of market dynamics.
#   - Sources: News, geop olitical events, or trader psychology can drive market sentiment.
#   - Discussion: Even if all economic indicators point in a particular direction, unforeseen events or shifts in trader
# sentiment can lead the market in a different direction. AI bots need to  factor in sentiment analysis for a holistic trading
# strategy.
#
# e. Unforeseen Black Swan Events
#   - Definition: Unexpected events that have significant and often negative consequences.
#   - Importance: These events can abruptly change the course of the mark et, rendering predictions based on economic
# indicators ineffective.
#   - Sources: Natural disasters, geopolitical conflicts, global pandemics, and other unpredictable events.
#   - Discussion: While AI can be trained on past data, predicting or accounting for  black swan events remains
# challenging due to their unpredictable nature.
#
# 6. Conclusion
#
# AI currency trading bots offer the promise of automating complex trading strategies in the dynamic world of forex,
# using data -driven methods that outpace human analys is in both speed and volume. Economic indicators, both major
# and minor, play a pivotal role in shaping these strategies.
#
#
# 7. Benefits:
#    a. Automation: AI trading bots can monitor multiple economic indicators across various regions simultaneously,
# ensuring no crucial data point is missed.
#    b. Predictive Power: Leveraging machine learning, these bots can discern patterns from historical data, enabling
# them to forecast potential market movements based on economic indicators.
#    c. Risk Management: AI bots can adapt trading strategies in real -time based on the latest economic data, helping to
# minimize losses and capitalize on profitable opportunities.
#
# Challenges:
#    a. Data Integrity: The accuracy and timeliness of economic data remai n critical. Any misinterpretation or reliance on
# incorrect data can significantly impact trading outcomes.
#    b. Complex Market Dynamics: Beyond quantitative economic indicators, forex markets are influenced by qualitative
# factors like geopolitical events,  trader sentiment, and unforeseen black swan events.
#    c. Model Limitations: Overfitting and other model -related challenges can skew predictions, emphasizing the need
# for continuous model validation and refinement.
#  Future Outlook:
# As AI and machine learn ing technologies evolve, so will their capability to understand and predict forex market
# dynamics. Integration of sentiment analysis, alternative data sources, and enhanced predictive algorithms can offer
# more nuanced and comprehensive trading strategies.
#
# However, traders and developers alike should approach with caution. While AI offers enhanced capabilities, the forex
# market's inherent unpredictability means there will always be potential catastrophic element of risk  present . Balancing
# AI's potential wit h a sound understanding of its limitations is key to successful and sustainable forex trading in the
# future.
#
#
# Appendices J: Description of Other Data Sources for AI Currency Trading Bot
#
#
# 1. Social Media
#
#   - Definition: Platforms where individuals and entities share opinions, news, and information. Examples include
# Twitter, Facebook, LinkedIn, and Reddit.
#   - Importance: Real -time sentiment analysis, detection of trends, and anticipation of market movements based on the
# collective consci ousness.
#   - Sources: Direct APIs (e.g., Twitter API), third -party data aggregators.
#   - Discussion: Sentiment analysis on social media can gauge public opinion on economic events, political decisions,
# or market predictions. However, the challenge lies in distinguishing genuine insights from noise and potential
# misinformation.
#
#
# 2. Influencers
#
#   - Definition: Individuals with significant following and influence over public opinion in financial markets, including
# prominent traders, economic analysts, or fin ancial journalists.
#   - Importance: Their opinions can sway market sentiment or introduce new perspectives that can lead to market
# movement.
#   - Sources: Blogs, personal websites, YouTube channels, financial news outlets.
#   - Discussion: While influencers can provide valuable insights, AI bots should evaluate the historical accuracy and
# biases of these sources. Their opinions can sometimes be based on personal interests or affiliations.
#
#
# 3. Political Organizations and Lobbyists
#
#   - Definition: Groups that  influence political decisions, often in favor of specific industries or interests.
#   - Importance: Anticipating policy changes or economic decisions that can impact currency value.
#   - Sources: Political statements, lobbying disclosures, campaign contribu tions, governmental websites.
#   - Discussion: Understanding the agendas of these groups can offer insights into potential policy shifts, which might
# impact economic health and currency strength. However, this data should be used cautiously due to potential  bias
# and hidden agendas.
#
#
# 4. Biased Tech Platforms
#
#   - Definition: Technology platforms, including search engines or news aggregators, that might have inherent biases in
# their algorithms, impacting the information they present.
#   - Importance: Recognizi ng and accounting for these biases can ensure a more balanced data interpretation.
#   - Sources: Platform algorithms, user feedback, third -party evaluations.
#   - Discussion: AI bots should be wary of taking data from these platforms at face value. A thoroug h understanding of
# potential biases and cross -referencing with neutral sources can offer a more accurate picture.
#
#
# Conclusion:
#
# Incorporating these alternative data sources into an AI currency trading bot's framework can offer a broader
# understanding of m arket dynamics. However, challenge continue  in ensuring application of relevant data, determining
# data accuracy, recognizing biases, and filtering out noise  and relating these data sources directly to the specific strategy chosen for AI currency trading bo t. Rigorous data validation, continuous model refinement, and a healthy
# dose of skepticism are crucial when integrating these sources into a trading strategy.
#
#
# Appendices K: Supplemental Visual Aids
#
# Graphs for comparisons
# line graphs showcasing drawdown and recovery periods
# pie charts illustrating portfolio diversification
# Performance graphs over time
# tables/performance metrics against benchmarks
# visual diagrams of the model architecture
# flowcharts
# snippets of code or pseudocode for technical aud iences
# Statistical evidence
# effectiveness of strategies
# potential case studies
# (simulations comparing the bot's performance with and without these risk minimization techniques)
#
# LIVE TRADING
#    Example: Showing Opt -In Strategy.
#         (note: movement of currency pairs in a downward motion has no bearing on profit/loss metrics, as the hybrid
# model, as constructed, promotes instantaneous transitions between trading strategy, triggered by real -time market
# analysis.
#
#
#
#
#
#
#
# LIVE TESTING 3 -month
#
#
#
#
#
#
#
#
#
#
#
# Appendices L:  Ethics Reference  Material
#
# We stand on the shoulders of past and present day big thinkers, and only attempt to follow the path that our
# technological leaders have paved before us.
#
# 1. Book: *“Weapons of Math Destruction: How Big Data Increases Inequality and Threatens Democracy”* by Cathy
# O'Neil.
#
#   Quote: “Big data processes codify the past. They do not invent the future. Doing that requires moral imagination,
# and that’s something only humans can provide. We have to explicitly embed better values into our algorithms,
# creating Big Data models that follow our ethical lead.”
#
# 2. Article: *“Ethical Algorithms: Bias and Explainability in Machine Learning Systems”* from Harvard Business
# Review.
#
#   Quote: “As machine  learning systems become more complex and more influential in major industries and everyday
# life, the stakes for fairness, reliability, and transparency will be higher than ever.”
#
# 3. Publication: *“Ethics Guidelines for Trustworthy AI”* by the European Co mmission's High -Level Expert Group on
# Artificial Intelligence.
#
#   Quote: “Trustworthy AI has three components: it should be lawful, complying with all applicable laws and
# regulations; it should be ethical, ensuring adherence to ethical principles and value s; and it should be robust, from
# both a technical and social perspective.”
#
# 4. Article: *“The Ethics of Artificial Intelligence”* by Nick Bostrom and Eliezer Yudkowsky, Cambridge Handbook of
# Artificial Intelligence.
#
#   Quote: “Just as we have ethical oblig ations toward other humans – to respect their autonomy and the core of their
# personhood and various derived rights – we might be able to discern similar obligations toward future AI.”
#
# 5. Book: *“Moral Machines: Teaching Robots Right from Wrong”* by Wendel l Wallach and Colin Allen.
#   Quote: “When machines surpass human intelligence, we might not even be able to understand the strategies they
# develop for learning and decision -making. Hence, we need to set up the initial conditions and moral algorithms in
# such a way that ensures their safe and beneficial operation.”
#
#  6. Research Paper: *“Algorithmic Trading in the Foreign Exchange Market”* by Martin D.D. Evans.
#  Source: Journal of Finance
# Derivative Material: An in -depth analysis of how algorithmic trading in fluences the foreign exchange market, its price
# dynamics, and liquidity.
#
#   7. White Paper: *“Machine Learning for Trading”* by Manoj Kumar.
# Source: Nanyang Technological University
# Derivative Material: A comprehensive dive into the potential and pitfalls of machine learning in trading, examining
# various strategies and their performances.
#
#   8. Research Paper: *“High -frequency trading in the foreign exchange market”* by Nikolaus Hautsch, Lada M. Kyj,
# and Roel C.A. Oomen.
# Source: Journal of International Mon ey and Finance
# Derivative Material: A study into the implications of high -frequency trading in forex markets, focusing on its impact on
# market quality.
#
#   9. White Paper: *“Ethics of Artificial Intelligence and Robotics”* by Vincent C. Müller.
# Source: Stan ford Encyclopedia of Philosophy
# Derivative Material: A deep examination into the ethical concerns of AI and robotics, focusing on the challenges of
# ensuring moral responsibility in machine behavior.
#
#  10. Research Paper: *“Financial Time Series Prediction using Deep Learning”* by Yun -Cheng Tsai and Jun -Hao
# Chen.
# Source: Archives of Computational Methods in Engineering
# Derivative Material: An exploration into the use of deep learning techniques for predicting financial time series,
# evaluating their efficacy over traditional models.
#
#  11. White Paper: *“Trust and Transparency in AI”* by OpenAI.
# Source: OpenAI
# Derivative Material: OpenAI's respected perspective  and guide  on the importance of building trust and ensuring
# transparency uniformly in AI models, with sourced discussions of  both technical and philosophical considerations .
#
# 12. Research Paper: *“Algorithmic Governance in Smart Cities”* by Rob Kitchin.
# Source: Annals of the American Association of Geographers
# Derivative Material: While centered on smart cities, this paper sheds light on the broader topic of algorithmic
# governance and its ethical implications – relevant to any system making automated decisions.
#
#
# Overall Ethical Mission Statement:
#
# "Our AI Currency Trading Bot, inspired by foundation al principles of fairness, transparency, and accountability, is
# committed to the highest ethical standards in both forex trading and computer science. Drawing from leading thinkers
# in the domain, we recognize the immense responsibility that comes with inte grating responsible AI in financial
# markets. We pledge to be diligent, transparent, and consistently guided by ethical considerations in every iteration
# and deployment, striving to produce reliable and fair technology that not only meets performance metric s but also
# serves broader societal values."

# %% [markdown]
# ### Combine code ( extracting text from pdf and summarizing it) (model = t5-small)

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def generate_summary(text):
    model_name = "t5-small"
    tokenizer = T5Tokenizer.from_pretrained(model_name)
    model = T5ForConditionalGeneration.from_pretrained(model_name)

    inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=512, truncation=True)

    summary_ids = model.generate(inputs, max_length=150, num_beams=4, length_penalty=2.0, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

pdf_path = r"C:\Users\MD\Downloads\“AI OPTIMIZED QUANTUM FOREX BOT TO ENHANCE PHILANTHROPY Evolution and Future Developments”  .pdf"

text = extract_text_from_pdf(pdf_path)

summary = generate_summary(text)

print("Summary : ",summary)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Summary :  currency trading stands as one of its most intricate and dynamic components. the digital revolution has greatly democratized access, with a myriad of platforms now enabling anyone to try their hand at predicting the rise and fall of currency values. integrating AI into currency trading isn't just about automating trades, but about leveraging the power of AI to make more informed decisions.

# %% [raw]
# def extract_text_from_pdf(pdf_path):
#     text = ""
#     with open(pdf_path, 'rb') as file:
#         pdf_reader = PyPDF2.PdfReader(file)
#         for page in pdf_reader.pages:
#             text += page.extract_text()
#     return text
#
# def generate_summary(text):
#     model_name = "t5-small"
#     tokenizer = T5Tokenizer.from_pretrained(model_name)
#     model = T5ForConditionalGeneration.from_pretrained(model_name)
#
#     inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=512, truncation=True)
#     ## Changing the arguments for different o/p
#     summary_ids = model.generate(inputs, max_length=512*2, num_beams=4, length_penalty=2.0, early_stopping=False)
#     summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#     return summary
#
# pdf_path = r"C:\Users\MD\Downloads\“AI OPTIMIZED QUANTUM FOREX BOT TO ENHANCE PHILANTHROPY Evolution and Future Developments”  .pdf"
#
# text = extract_text_from_pdf(pdf_path)
#
# summary = generate_summary(text)
#
# print(summary)
#
# Output :
#
# currency trading stands as one of its most intricate and dynamic components. the digital revolution has greatly democratized access, with a myriad of platforms now enabling anyone to try their hand at predicting the rise and fall of currency values. the sheer volume of global transactions, occurring 24/7, means even s easoned traders find it challenging to keep pace with the market's movements, let alone consistently make profitable decisions. this new landscape has necessitate the exploration of advanced technologies to aid in trading decisions

# %% [markdown]
# ### Breaking the code for better understanding

# %% [raw]
# model_name = "t5-small"
# tokenizer = T5Tokenizer.from_pretrained(model_name)
# model = T5ForConditionalGeneration.from_pretrained(model_name)

# %% [markdown]
# 1. **Tokenizer Initialization**: The `T5Tokenizer.from_pretrained(model_name)` line initializes a tokenizer for the T5 model specified by `model_name`. A tokenizer is responsible for converting raw text input into tokenized format that can be understood by the model. It handles tasks such as splitting words into subwords, adding special tokens, and converting tokens to numerical IDs.
#
# 2. **Model Initialization**: The `T5ForConditionalGeneration.from_pretrained(model_name)` line initializes a T5 model for conditional generation using the specified `model_name`. This model is pre-trained on a large corpus of text data and fine-tuned for various natural language processing tasks, including text summarization. The model takes tokenized input and generates output based on the task it's designed for. In this case, the model is designed for conditional generation, which means it can generate text sequences conditioned on some input.
#
# Overall, these lines set up the tokenizer and the T5 model for conditional generation, allowing you to tokenize input text and generate summaries using the T5 model architecture.

# %% [raw]
# inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=512, truncation=True)

# %% [markdown]
# 1. **Text Encoding**: The `tokenizer.encode()` method is used to encode the input text into numerical tokens suitable for the T5 model. The input text is prefixed with "summarize: " to indicate to the model that it should generate a summary of the provided text. The `tokenizer.encode()` method converts the text into a list of token IDs.
#
# 2. **PyTorch Tensors**: The `return_tensors="pt"` argument specifies that the output should be returned as PyTorch tensors. PyTorch tensors are multi-dimensional arrays that can be processed by the T5 model. This allows the input data to be compatible with the T5 model's processing requirements.
#
# 3. **Maximum Length and Truncation**: The `max_length=512` argument specifies the maximum length of the encoded input sequence. If the input text exceeds this length, it will be truncated to fit within the specified limit. The `truncation=True` argument indicates that truncation should be applied if necessary to ensure that the input sequence does not exceed the maximum length.
#
# Overall, this line encodes the input text into numerical tokens, converts it into PyTorch tensors, and applies truncation if needed to prepare it for input to the T5 model for summary generation.

# %% [raw]
# summary_ids = model.generate(inputs, max_length=150, num_beams=4, length_penalty=2.0, early_stopping=True)

# %% [markdown]
# This line of code is responsible for generating the summary using the T5 model. Let's break down the arguments used in the `generate` method:
#
# 1. **inputs**: This is the input data provided to the model for generating the summary. It typically consists of token IDs representing the input text. In this case, it's the tokenized representation of the input text obtained using the tokenizer.
#
# 2. **max_length**: This parameter specifies the maximum length of the generated summary in terms of tokens. In this code, the maximum length of the summary is set to 150 tokens. This means that the generated summary will contain at most 150 tokens.
#
# 3. **num_beams**: This parameter controls the number of beams used in beam search decoding. Beam search is a technique used in sequence generation tasks like text summarization to generate multiple candidate sequences simultaneously. The `num_beams` parameter specifies the number of beams to use. In this code, `num_beams` is set to 4, which means that the model will consider 4 candidate sequences during decoding.
#
# 4. **length_penalty**: This parameter is used to control the trade-off between the length of the generated summary and its probability. A higher length penalty encourages the model to generate shorter summaries, while a lower length penalty allows for longer summaries. In this code, `length_penalty` is set to 2.0, indicating a moderate preference for shorter summaries.
#
# 5. **early_stopping**: This parameter determines whether to stop decoding when all beams have reached the end-of-sequence token. If set to `True`, decoding will stop when at least one beam has reached the end-of-sequence token. This helps prevent the generation of overly long sequences. In this code, `early_stopping` is set to `True`.
#
# Overall, this line of code generates the summary using the T5 model with specified parameters for maximum length, beam search, length penalty, and early stopping. The generated summary is represented as a sequence of token IDs (`summary_ids`). Later, this sequence is decoded into human-readable text using the tokenizer.

# %% [raw]
# summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %% [markdown]
# 1. **summary_ids[0]**: `summary_ids` is a list of sequences of token IDs representing the generated summaries. Since we typically generate only one summary, `summary_ids[0]` selects the first (and usually the only) sequence of token IDs from the list.
#
# 2. **skip_special_tokens=True**: This parameter instructs the tokenizer to skip special tokens during decoding. Special tokens include tokens like `[CLS]`, `[SEP]`, and padding tokens, which are not part of the actual text content but are used for formatting and padding purposes. By setting `skip_special_tokens=True`, we ensure that these special tokens are not included in the final decoded text.
#
# Overall, this line of code takes the sequence of token IDs representing the generated summary (`summary_ids[0]`) and converts it into human-readable text, excluding any special tokens, using the tokenizer. The resulting text is assigned to the variable `summary`, which represents the final generated summary in natural language form.

# %% [markdown]
# ### t5-base

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def generate_summary(text):
    model_name = "t5-base"
    tokenizer = T5Tokenizer.from_pretrained(model_name)
    model = T5ForConditionalGeneration.from_pretrained(model_name)

    inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=512, truncation=True)

    summary_ids = model.generate(inputs, max_length=150, num_beams=4, length_penalty=2.0, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

pdf_path = r"C:\Users\MD\Downloads\“AI OPTIMIZED QUANTUM FOREX BOT TO ENHANCE PHILANTHROPY Evolution and Future Developments”  .pdf"

text = extract_text_from_pdf(pdf_path)

summary = generate_summary(text)

print("Summary : ",summary)
# Out:
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# C:\Users\MD\anaconda3\lib\site-packages\huggingface_hub\file_download.py:148: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\MD\.cache\huggingface\hub\models--t5-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Summary :  integrating AI into currency trading isn't just about automating trades. it's about leveraging the power of AI to make more informed decisions. as potential rewards grow, so too do potential losses. this white paper delves into the creation, development and maturation of an AI -driven currency trading software bot.

# %% [markdown]
# ### t5-large

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, 'rb') as file:
        pdf_reader = PyPDF2.PdfReader(file)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def generate_summary(text):
    model_name = "t5-large"
    tokenizer = T5Tokenizer.from_pretrained(model_name)
    model = T5ForConditionalGeneration.from_pretrained(model_name)

    inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=512, truncation=True)

    summary_ids = model.generate(inputs, max_length=150, num_beams=4, length_penalty=2.0, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

pdf_path = r"C:\Users\MD\Downloads\“AI OPTIMIZED QUANTUM FOREX BOT TO ENHANCE PHILANTHROPY Evolution and Future Developments”  .pdf"

text = extract_text_from_pdf(pdf_path)

summary = generate_summary(text)

print("Summary : ",summary)
# Out:
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# C:\Users\MD\anaconda3\lib\site-packages\huggingface_hub\file_download.py:148: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\MD\.cache\huggingface\hub\models--t5-large. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# Summary :  integrating AI into currency trading isn't just about automating trades. it's about leveraging the power of AI to make more informed decisions. the objective isn't merely profitability; it's sustainable and responsible profitability. integrating AI into currency trading isn't just about automating trades.

# %% [markdown]
# ## Over here a question arises which t5 model to use ?
#
# The accuracy of a T5 model for text summarization depends on various factors, including the size of the model, the quality and quantity of the training data, and the specific characteristics of the text to be summarized. Generally, larger T5 models tend to have higher accuracy, but they also require more computational resources.
#
# Here's a general guideline for choosing a T5 model variant for text summarization:
#
# 1. **t5-small**: This variant is smaller and faster but may sacrifice some accuracy compared to larger models. It's suitable for quick experimentation or when computational resources are limited.
#
# 2. **t5-base**: This is a mid-sized variant that balances performance and computational cost. It's a good choice for many text summarization tasks and is widely used in practice.
#
# 3. **t5-large**: This variant has more parameters and can potentially achieve higher accuracy, especially for more complex summarization tasks or when summarizing longer documents. However, it requires more memory and computational resources to train and use.
#
# 4. **t5-3b**, **t5-11b**: These are even larger variants with significantly more parameters. They are suitable for tasks where very high accuracy is required or when dealing with extremely large datasets. However, they are also the most resource-intensive and may not be practical for all use cases.
#
# When choosing a T5 model variant, consider your specific requirements in terms of accuracy, computational resources, and speed. It's often a trade-off between these factors, so you may need to experiment with different variants to find the best balance for your particular text summarization task.
